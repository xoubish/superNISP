# %% [markdown]
# # PSFs in NISP MER images

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
from matplotlib.colors import LogNorm

# %% [markdown]
# ## catalog files

# %%
d = fits.open('../data/NISP-Y/HUDF/PSFs/EUC_MER_CATALOG-PSF-NIR-Y_TILE102044185-B0A5EA_20241021T060047.722344Z_00.00.fits')
d.info()
# Out:
# Filename: ../data/NISP-Y/HUDF/PSFs/EUC_MER_CATALOG-PSF-NIR-Y_TILE102044185-B0A5EA_20241021T060047.722344Z_00.00.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  PSF image     1 ImageHDU        48   (10362, 10362)   float32
#   2  Stamps information    1 BinTableHDU     23   98253R x 7C   [D, D, D, D, D, D, D]

# %%
d = fits.getdata('../data/NISP-Y/HUDF/PSFs/EUC_MER_CATALOG-PSF-NIR-Y_TILE102044185-B0A5EA_20241021T060047.722344Z_00.00.fits',1)
plt.imshow(d[100:500, 100:500], norm=LogNorm(vmin=0.000001, vmax=0.05),origin='lower')
plt.colorbar()
plt.show()

# %% [markdown]
# ## Grid files

# %%
d = fits.open('../data/NISP-Y/HUDF/PSFs/EUC_MER_GRID-PSF-NIR-Y_TILE102044185-7B0C0_20241021T003716.460604Z_00.00.fits')
d.info()
# Out:
# Filename: ../data/NISP-Y/HUDF/PSFs/EUC_MER_GRID-PSF-NIR-Y_TILE102044185-7B0C0_20241021T003716.460604Z_00.00.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  PSF image     1 ImageHDU        48   (19200, 19200)   float32
#   2  Stamps information    1 BinTableHDU     15   25530R x 3C   [D, D, D]

# %%
d = fits.getdata('../data/NISP-Y/hudf/PSFs/EUC_MER_GRID-PSF-NIR-Y_TILE102044185-7B0C0_20241021T003716.460604Z_00.00.fits',1)
plt.imshow(d[100:500, 100:500], norm=LogNorm(vmin=0.000001, vmax=0.05),origin='lower')
plt.colorbar()
plt.show()
